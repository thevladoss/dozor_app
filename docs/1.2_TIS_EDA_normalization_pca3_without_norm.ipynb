# %%
import pandas as pd

# %%
df = pd.read_csv('../data/butter_rgb.csv')
df.head()
# Out:
#      R    G    B
# 0  144  205  146
# 1  151  206  179
# 2  154  203  167
# 3  138  218  245
# 4  159  227  189

# %%
# Use PCA for dimensionality reduction and plot the first two components
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=3)
pca.fit(df)
X = pca.transform(df)

plt.scatter(X[:, 0], X[:, 1])

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()

plt.show()

# %%
# Predict pca for new rgb values
new_rgb = [[255, 0, 0], [0, 255, 0], [0, 0, 255]]
new_rgb = pca.transform(new_rgb)

# Plot new rgb values
plt.scatter(X[:, 0], X[:, 1])
plt.scatter(new_rgb[:, 0], new_rgb[:, 1], color='red')

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()

plt.show()
# Out:
# /home/quakumei/.conda/envs/py39/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
# Cluster data using Agglomerative Hierarchical Clustering (AHC)
from sklearn.cluster import AgglomerativeClustering

# Use Entropy truncation
ahc = AgglomerativeClustering(n_clusters=4, linkage='ward', affinity='euclidean')
ahc.fit(X)

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=ahc.labels_)

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()

plt.show()

# %%
# Write which colors match which clusters
for i in range(4):
    print('Cluster', i, 'contains', df[ahc.labels_ == i].index.values)
# Out:
# Cluster 0 contains [ 3 11 12 13 14 24 31]
# Cluster 1 contains [ 4  5  6  7  8 15 17 18 19 20 22 23 26 27 29 30]
# Cluster 2 contains [ 0  9 10 16 25]
# Cluster 3 contains [ 1  2 21 28]

# %% [markdown]
# 2 = 3

# %%
# Append cluster labels to dataframe
df['cluster'] = ahc.labels_
df.head()
# Out:
#      R    G    B  cluster
# 0  144  205  146        2
# 1  151  206  179        3
# 2  154  203  167        3
# 3  138  218  245        0
# 4  159  227  189        1

# %%
# Replace cluster label 3 with 2
df['cluster'] = df['cluster'].replace(3, 2)

# %%
# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=df['cluster'])

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()

plt.show()

# %%
label_table = {
    0: 'сливочное',
    1: 'кокосовое',
    2: 'фальсификат',
}

# Replace cluster labels with names
df['cluster'] = df['cluster'].replace(label_table)

# %%
df.head()
# Out:
#      R    G    B      cluster
# 0  144  205  146  фальсификат
# 1  151  206  179  фальсификат
# 2  154  203  167  фальсификат
# 3  138  218  245    сливочное
# 4  159  227  189    кокосовое

# %%
# Write to csv
df.to_csv('../data/butter_rgb_with_labels.csv', index=False)

# %%
# Reverse replace
df['cluster'] = df['cluster'].replace({v: k for k, v in label_table.items()})
df.head()
# Out:
#      R    G    B  cluster
# 0  144  205  146        2
# 1  151  206  179        2
# 2  154  203  167        2
# 3  138  218  245        0
# 4  159  227  189        1

# %%
# to csv
df.to_csv('../data/butter_rgb_with_labels_numbers.csv', index=False)

# %%
# Plot three-dimensional clusters according to rgb values
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['R'], df['G'], df['B'], c=df['cluster'])

ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')

plt.show()

# %%
# Train KNN classifier on the RGB and cluster labels and compare performance
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df[['R', 'G', 'B']], df['cluster'], test_size=0.2, random_state=42)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Predict labels
y_pred = knn.predict(X_test)

# Calculate accuracy
print("KNN on RGB accuracy:", accuracy_score(y_test, y_pred))
# Out:
# KNN on RGB accuracy: 1.0

# %%
import numpy as np

# %%
# Train KNN classifier on the PCA and cluster labels and compare performance
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, df['cluster'], test_size=0.2, random_state=42)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Predict labels
y_pred = knn.predict(X_test)

# Calculate accuracy
print("KNN on PCA accuracy:", accuracy_score(y_test, y_pred))


# Plot the division of space into clusters for KNN on PCA

# Create meshgrid
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05), np.arange(y_min, y_max, 0.05))

# Predict labels for each point in the meshgrid
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.4)


# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=df['cluster'], alpha=0.8)

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()

plt.show()
# Out:
# KNN on PCA accuracy: 1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [36], line 24
#      21 xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05), np.arange(y_min, y_max, 0.05))
#      23 # Predict labels for each point in the meshgrid
# ---> 24 Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
#      25 Z = Z.reshape(xx.shape)
#      27 # Plot the decision boundary
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:219, in KNeighborsClassifier.predict(self, X)
#     203 """Predict the class labels for the provided data.
#     204
#     205 Parameters
#    (...)
#     214     Class labels for each data sample.
#     215 """
#     216 if self.weights == "uniform":
#     217     # In that case, we do not need the distances to perform
#     218     # the weighting so we do not compute them.
# --> 219     neigh_ind = self.kneighbors(X, return_distance=False)
#     220     neigh_dist = None
#     221 else:
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/sklearn/neighbors/_base.py:745, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     743         X = _check_precomputed(X)
#     744     else:
# --> 745         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#     747 n_samples_fit = self.n_samples_fit_
#     748 if n_neighbors > n_samples_fit:
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/sklearn/base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 2 features, but KNeighborsClassifier is expecting 3 features as input.

# %%
# Train KNN classifier on the PCA values, but make the distribution of groups equal
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, df['cluster'], test_size=0.2, random_state=42, stratify=df['cluster'])

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Predict labels
y_pred = knn.predict(X_test)

# Calculate accuracy
print("KNN on PCA with equal distribution of groups accuracy:", accuracy_score(y_test, y_pred))
# Out:
# KNN on PCA with equal distribution of groups accuracy: 1.0

# %%
# Train tree classifier
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)

# Predict labels
y_pred = tree.predict(X_test)

# Calculate accuracy
print("Tree on PCA accuracy:", accuracy_score(y_test, y_pred))

# Plot the division of space into clusters for tree on PCA

# Create meshgrid
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05), np.arange(y_min, y_max, 0.05))

# Predict labels for each point in the meshgrid
Z = tree.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.4)



# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=df['cluster'], alpha=0.8)

# Draw axis
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')

# Label axis
plt.xlabel('PC1')
plt.ylabel('PC2')

# Grid
plt.grid()
plt.show()
# Out:
# Tree on PCA accuracy: 1.0

# %%
# pca coefs
pca.components_
# Out:
# array([[-0.24520308,  0.11216704,  0.96296106],
#        [ 0.7728561 ,  0.62228628,  0.12431103]])

# %%
# Print average color of each cluster
for i in range(3):
    print('Cluster', i)
    print('R:', df[df['cluster'] == i]['R'].mean())
    print('G:', df[df['cluster'] == i]['G'].mean())
    print('B:', df[df['cluster'] == i]['B'].mean())

    # SHOW COLOR HEX-lIKE
    print('HEX:', '#%02x%02x%02x' % (round(df[df['cluster'] == i]['R'].mean()), round(df[df['cluster'] == i]['G'].mean()), round(df[df['cluster'] == i]['B'].mean())))
# Out:
# Cluster 0
# R: 130.57142857142858
# G: 217.57142857142858
# B: 234.85714285714286
# HEX: #83daeb
# Cluster 1
# R: 158.75
# G: 223.1875
# B: 185.0625
# HEX: #9fdfb9
# Cluster 2
# R: 151.11111111111111
# G: 203.44444444444446
# B: 154.44444444444446
# HEX: #97cb9a

# %%
# Get PCA components
pca.components_
# Out:
# array([[-0.24520308,  0.11216704,  0.96296106],
#        [ 0.7728561 ,  0.62228628,  0.12431103]])

# %%
# Check ortoganality
np.dot(pca.components_[0], pca.components_[1])
# Out:
# -1.6653345369377348e-16
